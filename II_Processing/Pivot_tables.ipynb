# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Создание сводных таблиц
#
# - Статья в документации pandas, посвященная изменению формы таблиц - https://pandas.pydata.org/docs/user_guide/reshaping.html
# - Хороший туториал по этой теме - https://towardsdatascience.com/pandas-pivot-the-ultimate-guide-5c693e0771f3

# %%
df = pd.DataFrame({
    'datetime': pd.date_range('1/1/2000', periods=9, freq='T'),
    'oper': ['A','B', 'A','C','C','C','A','A','B'],
    'reaction': [1,2,1,3,2,3,2,1,2],
    'chat_id': ['1000','1001','1002','1003','1004','1005','1006','1007','1008']
})

opers = df['oper'].unique()

df
# Out:
#              datetime oper  reaction chat_id
# 0 2000-01-01 00:00:00    A         1    1000
# 1 2000-01-01 00:01:00    B         2    1001
# 2 2000-01-01 00:02:00    A         1    1002
# 3 2000-01-01 00:03:00    C         3    1003
# 4 2000-01-01 00:04:00    C         2    1004
# 5 2000-01-01 00:05:00    C         3    1005
# 6 2000-01-01 00:06:00    A         2    1006
# 7 2000-01-01 00:07:00    A         1    1007
# 8 2000-01-01 00:08:00    B         2    1008

# %%
# Продублируем последнюю строку
wdf = df.append(
    pd.DataFrame({
        'datetime': [dt.datetime(2000,1,1,0,8,0)], 
        'oper': ['B'], 
        'reaction': [2],
        'chat_id': ['1009']
    })
)
wdf
# Out:
#              datetime oper  reaction chat_id
# 0 2000-01-01 00:00:00    A         1    1000
# 1 2000-01-01 00:01:00    B         2    1001
# 2 2000-01-01 00:02:00    A         1    1002
# 3 2000-01-01 00:03:00    C         3    1003
# 4 2000-01-01 00:04:00    C         2    1004
# 5 2000-01-01 00:05:00    C         3    1005
# 6 2000-01-01 00:06:00    A         2    1006
# 7 2000-01-01 00:07:00    A         1    1007
# 8 2000-01-01 00:08:00    B         2    1008
# 0 2000-01-01 00:08:00    B         2    1009

# %% [markdown]
# ## Метод pivot - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot.html

# %%
df1 = df.set_index('datetime')
df1 = df1.pivot(columns='oper', values='reaction')
df1
# Out:
# oper                   A    B    C
# datetime
# 2000-01-01 00:00:00  1.0  NaN  NaN
# 2000-01-01 00:01:00  NaN  2.0  NaN
# 2000-01-01 00:02:00  1.0  NaN  NaN
# 2000-01-01 00:03:00  NaN  NaN  3.0
# 2000-01-01 00:04:00  NaN  NaN  2.0
# 2000-01-01 00:05:00  NaN  NaN  3.0
# 2000-01-01 00:06:00  2.0  NaN  NaN
# 2000-01-01 00:07:00  1.0  NaN  NaN
# 2000-01-01 00:08:00  NaN  2.0  NaN

# %% [markdown]
# #### В принципе pivot делает то же, что и эта команда
# <img src="data/img/reshaping_unstack.png" width="500">

# %%
df.set_index(["datetime", "oper"])["reaction"].unstack()
# Out:
# oper                   A    B    C
# datetime
# 2000-01-01 00:00:00  1.0  NaN  NaN
# 2000-01-01 00:01:00  NaN  2.0  NaN
# 2000-01-01 00:02:00  1.0  NaN  NaN
# 2000-01-01 00:03:00  NaN  NaN  3.0
# 2000-01-01 00:04:00  NaN  NaN  2.0
# 2000-01-01 00:05:00  NaN  NaN  3.0
# 2000-01-01 00:06:00  2.0  NaN  NaN
# 2000-01-01 00:07:00  1.0  NaN  NaN
# 2000-01-01 00:08:00  NaN  2.0  NaN

# %% [markdown]
# ##### А вот если в индексах или колонках есть дубликаты - pivot ломается

# %%
df1 = wdf.set_index('datetime')
df1 = df1.pivot(columns='oper', values='reaction')
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f1dec160bc88> in <module>
#       1 df1 = wdf.set_index('datetime')
# ----> 2 df1 = df1.pivot(columns='oper', values='reaction')
#       3 df1
#
# /DataScience/safonkin/PycharmProjects/service/venv/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# /DataScience/safonkin/PycharmProjects/service/venv/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517     return indexed.unstack(columns_listlike)
#     518
#     519
#
# /DataScience/safonkin/PycharmProjects/service/venv/lib/python3.7/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    4079         from pandas.core.reshape.reshape import unstack
#    4080
# -> 4081         return unstack(self, level, fill_value)
#    4082
#    4083     # ----------------------------------------------------------------------
#
# /DataScience/safonkin/PycharmProjects/service/venv/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     459             return _unstack_extension_series(obj, level, fill_value)
#     460         unstacker = _Unstacker(
# --> 461             obj.index, level=level, constructor=obj._constructor_expanddim
#     462         )
#     463         return unstacker.get_result(
#
# /DataScience/safonkin/PycharmProjects/service/venv/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor)
#     131             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     132
# --> 133         self._make_selectors()
#     134
#     135     @cache_readonly
#
# /DataScience/safonkin/PycharmProjects/service/venv/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     183
#     184         if mask.sum() < len(self.index):
# --> 185             raise ValueError("Index contains duplicate entries, cannot reshape")
#     186
#     187         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# ##### Есть вариант получше

# %% [markdown]
# ## Метод pivot_table - https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# %%
df2 = wdf.set_index('datetime')
df2 = df2.pivot_table(index='datetime', columns='oper', values='chat_id', aggfunc='count')
df2
# Out:
# oper                   A    B    C
# datetime
# 2000-01-01 00:00:00  1.0  NaN  NaN
# 2000-01-01 00:01:00  NaN  1.0  NaN
# 2000-01-01 00:02:00  1.0  NaN  NaN
# 2000-01-01 00:03:00  NaN  NaN  1.0
# 2000-01-01 00:04:00  NaN  NaN  1.0
# 2000-01-01 00:05:00  NaN  NaN  1.0
# 2000-01-01 00:06:00  1.0  NaN  NaN
# 2000-01-01 00:07:00  1.0  NaN  NaN
# 2000-01-01 00:08:00  NaN  2.0  NaN

# %% [markdown]
# ##### Механизм работы pivot_table больше напоминает эту команду.

# %%
wdf.groupby(['datetime', 'oper']).reaction.sum().unstack()
# Out:
# oper                   A    B    C
# datetime
# 2000-01-01 00:00:00  1.0  NaN  NaN
# 2000-01-01 00:01:00  NaN  2.0  NaN
# 2000-01-01 00:02:00  1.0  NaN  NaN
# 2000-01-01 00:03:00  NaN  NaN  3.0
# 2000-01-01 00:04:00  NaN  NaN  2.0
# 2000-01-01 00:05:00  NaN  NaN  3.0
# 2000-01-01 00:06:00  2.0  NaN  NaN
# 2000-01-01 00:07:00  1.0  NaN  NaN
# 2000-01-01 00:08:00  NaN  4.0  NaN

# %% [markdown]
# ##### Здесь агрегирующая функция - это sum. Но в принципе мы можем применить любую функцию

# %% [markdown]
# #### С помощью метода stack можно свернуть сводную таблицу
# <img src="data/img/reshaping_stack.png" width="500">

# %%
df2.stack()
# Out:
# datetime             oper
# 2000-01-01 00:00:00  A       1.0
# 2000-01-01 00:01:00  B       1.0
# 2000-01-01 00:02:00  A       1.0
# 2000-01-01 00:03:00  C       1.0
# 2000-01-01 00:04:00  C       1.0
# 2000-01-01 00:05:00  C       1.0
# 2000-01-01 00:06:00  A       1.0
# 2000-01-01 00:07:00  A       1.0
# 2000-01-01 00:08:00  B       2.0
# dtype: float64

# %% [markdown]
# ## Как посчитать записи по заданным временным периодам? - метод resample

# %%
tmp_count = df2.resample('3min').count()
tmp_count
# Out:
# oper                 A  B  C
# datetime
# 2000-01-01 00:00:00  2  1  0
# 2000-01-01 00:03:00  0  0  3
# 2000-01-01 00:06:00  2  1  0

# %% [markdown]
# #### Чтобы превести индексацию к привычному виду, достаточно применить метод .reset_index()

# %%
tmp_count = tmp_count.reset_index()
tmp_count
# Out:
# oper            datetime  A  B  C
# 0    2000-01-01 00:00:00  2  1  0
# 1    2000-01-01 00:03:00  0  0  3
# 2    2000-01-01 00:06:00  2  1  0

# %% [markdown]
# #### Правда в этом случае сохранится название индекса. Это можно исправить

# %%
tmp_count = tmp_count.rename_axis(None).rename_axis(None, axis=1)
tmp_count
# Out:
#              datetime  A  B  C
# 0 2000-01-01 00:00:00  2  1  0
# 1 2000-01-01 00:03:00  0  0  3
# 2 2000-01-01 00:06:00  2  1  0

# %%
tmp_count['date'] = tmp_count.datetime.dt.date
tmp_count['time'] = tmp_count.datetime.dt.strftime('%H:%M')
tmp_count['all'] = tmp_count[opers].sum(axis=1)

tmp_count = tmp_count[['date','time','all', *opers]].fillna(0)

tmp_count
# Out:
#          date   time  all  A  B  C
# 0  2000-01-01  00:00    3  2  1  0
# 1  2000-01-01  00:03    3  0  0  3
# 2  2000-01-01  00:06    3  2  1  0

# %% [markdown]
# ### К счетным таблицам можно добавить heatmap

# %%
tmp_count = (
    tmp_count.style
             .format({col: "{}" for col in tmp_count.columns})
             .background_gradient(
                 subset=opers, # По каким колонкам считать heatmap 
                 axis=1, # 0 - считать по колонкам, 1 - считать по строкам
                 cmap='Greys' # выбор цвета
             )
)

tmp_count
# Out:
# <style type="text/css">
# #T_fecdc_row0_col3, #T_fecdc_row1_col5, #T_fecdc_row2_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_fecdc_row0_col4, #T_fecdc_row2_col4 {
#   background-color: #959595;
#   color: #f1f1f1;
# }
# #T_fecdc_row0_col5, #T_fecdc_row1_col3, #T_fecdc_row1_col4, #T_fecdc_row2_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_fecdc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >time</th>
#       <th class="col_heading level0 col2" >all</th>
#       <th class="col_heading level0 col3" >A</th>
#       <th class="col_heading level0 col4" >B</th>
#       <th class="col_heading level0 col5" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fecdc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fecdc_row0_col0" class="data row0 col0" >2000-01-01</td>
#       <td id="T_fecdc_row0_col1" class="data row0 col1" >00:00</td>
#       <td id="T_fecdc_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_fecdc_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_fecdc_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_fecdc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fecdc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fecdc_row1_col0" class="data row1 col0" >2000-01-01</td>
#       <td id="T_fecdc_row1_col1" class="data row1 col1" >00:03</td>
#       <td id="T_fecdc_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_fecdc_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_fecdc_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_fecdc_row1_col5" class="data row1 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_fecdc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fecdc_row2_col0" class="data row2 col0" >2000-01-01</td>
#       <td id="T_fecdc_row2_col1" class="data row2 col1" >00:06</td>
#       <td id="T_fecdc_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_fecdc_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_fecdc_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_fecdc_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
